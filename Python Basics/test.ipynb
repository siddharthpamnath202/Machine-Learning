# %%
print("Start")
# Out:
# Start

# %%
# Single line comment 
'''
Multi Line comment 
'''

name = "Siddharth"
surname = "Pamnath"

print(name)
# Out:
# Siddharth

# %%
# Indentation 

age = 32
if age > 30 :
    print("Age .. ",age)
else :
    print("Done")
# Out:
# Age ..  32

# %%
total = 1+2+3+4 
print(total)
# Out:
# 10

# %%
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
# Semantic in the python 
age = 32
name = "Siddharth"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
# Type Interference 

variable = 10 
print(type(variable))
variable = "Krishna"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age = 32
if age > 30 :
    print(age)
# Out:
# 32

# %%
# Code Example of indentation 
if True :
    print("Correct Indenetation")
    if False :
        print("This will not print")
    print("This will print")

print("Outside the if block ")
# Out:
# Correct Indenetation
# This will print
# Outside the if block
