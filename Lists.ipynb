# %% [markdown]
# Lists  - Lists are ordered mutable collection of items
#          They can contain items of different data types
#
# 1. Introduction to lists
# 2. Creating the Lists
# 3. Acceessing the list
# 4. Modifing List Elements
# 5. Sciling the Lists
# 6. Iteration Over Lists
# 7. Iterating Over Lists
# 8. List Comprehensions
# 9. Nested Lists
# 10. Pratical Examples and common errors

# %%
list = []
print(type(list))
# Out:
# <class 'list'>

# %%
name = ["Krishna", "Jack","Jacob",1,2,3,4,5]
print(name)
# Out:
# ['Krishna', 'Jack', 'Jacob', 1, 2, 3, 4, 5]

# %%
mixed_lists = [1,"Hello",3.14, True]
print(mixed_lists)
# Out:
# [1, 'Hello', 3.14, True]

# %%
# Acessing the list items 

fruits = ["Apple","Banana", "Cheery","Demo"]
fruits[0]
fruits.append("Dust")
print("After Append",fruits)
print(fruits[-1])
print(fruits[1:3])
print(fruits[-1:-3])
# Out:
# After Append ['Apple', 'Banana', 'Cheery', 'Demo', 'Dust']
# Dust
# ['Banana', 'Cheery']
# []

# %%
fruits[-1:]="watermelon"

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Cheery',
#  'Demo',
#  'w',
#  'a',
#  't',
#  'e',
#  'r',
#  'm',
#  'e',
#  'l',
#  'o',
#  'n']

# %%
fruits.insert(1,"banana")

# %%
fruits
# Out:
# ['Apple',
#  'banana',
#  'Banana',
#  'Cheery',
#  'Demo',
#  'w',
#  'a',
#  't',
#  'e',
#  'r',
#  'm',
#  'e',
#  'l',
#  'o',
#  'n']

# %%
fruits.remove("banana") # removing the first occurence of an item

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Cheery',
#  'Demo',
#  'w',
#  'a',
#  't',
#  'e',
#  'r',
#  'm',
#  'e',
#  'l',
#  'o',
#  'n']

# %%
# Remove and return the last 
demo = fruits.pop()
print(demo)
# Out:
# r

# %%
fruits
# Out:
# ['Apple', 'Banana', 'Cheery', 'Demo', 'w', 'a', 't', 'e']

# %%
fruits.index("Apple")
# Out:
# ['Apple', 'Banana', 'Cheery', 'Demo', 'w', 'a', 't', 'e']

# %%
fruits.insert(2,"banana")
fruits.count("Cheery")
# Out:
# 1

# %%
fruits
# Out:
# ['Apple', 'Banana', 'banana', 'banana', 'Cheery', 'Demo', 'w', 'a', 't', 'e']

# %%
fruits.sort() #sort the all the list

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Cheery',
#  'Demo',
#  'a',
#  'banana',
#  'banana',
#  'banana',
#  'e',
#  't',
#  'w']

# %%
fruits.reverse() # It will reverse the list

# %%
fruits
# Out:
# ['Apple',
#  'Banana',
#  'Cheery',
#  'Demo',
#  'a',
#  'banana',
#  'banana',
#  'banana',
#  'e',
#  't',
#  'w']

# %%
# Slicing lists 

number = [1,2,3,4,5,6,7]
number
print(number[2:4])
print(number[5:])
print(number[::-1])
# Out:
# [3, 4]
# [6, 7]
# [7, 6, 5, 4, 3, 2, 1]

# %%
number[::1]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
number[::2]
# Out:
# [1, 3, 5, 7]

# %%
number[::3]
# Out:
# [1, 4, 7]

# %%
## Iterating oveer list

for fruite in fruits:
    print(fruite)
# Out:
# Apple
# Banana
# Cheery
# Demo
# a
# banana
# banana
# banana
# e
# t
# w

# %%
for index,fruits in enumerate(fruits):
    print(index,fruits)
# Out:
# 0 Apple
# 1 Banana
# 2 Cheery
# 3 Demo
# 4 a
# 5 banana
# 6 banana
# 7 banana
# 8 e
# 9 t
# 10 w

# %%
# List Comprehension 
lst = []
for x in range(10):
    lst.append(x**2)

print(lst)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# Another new method
[x**2 for x in range (10)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# List Comprehenesion 
# Basic Syntax [expression for item in iterable ]
# With conditional logic [expression for item in iterable if condition]

square = [num**2 for num in range(10)]
square
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#List Comprehension with condition 

for i in range(10):
    if i%2 ==0:
        lst.append(i)

print(lst)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 0, 2, 4, 6, 8, 0, 2, 4, 6, 8]

# %%
lst1 = [1,2,34,5]
lst2 = ['a','d','d']

pair = [[i,j]for i in lst1 for j in lst2]
print(pair)
# Out:
# [[1, 'a'], [1, 'd'], [1, 'd'], [2, 'a'], [2, 'd'], [2, 'd'], [34, 'a'], [34, 'd'], [34, 'd'], [5, 'a'], [5, 'd'], [5, 'd']]

# %%
# List compresionn with function calls 
words = ["Heloo","world","python"]
lenght = [len(words)]
