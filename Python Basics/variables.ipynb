# %% [markdown]
# # Variablles in the python datatype .
# # Introducton to variables
# # Declaring and assigning variables
# # Naming Conventions
# # Understanding Variable Types
# # Type Checking and conversion
# # Pratical Examples and Common Errors

# %%
a = 100

# %%
# Declaring and assigning variables 
age = 32
height = 2.3
name = "Krishna"
is_student = True

# Printing the variables 

print("age : ",age)
print("Height : ",height)
print("Name : ",name)
# Out:
# age :  32
# Height :  2.3
# Name :  Krishna

# %%
# Naming Conventions
# Variables name should be description 
# They must start with a letter or an '-' and contains letter , numbers and underscore
# Variables names case sensitive

# Variable names

first_name = "Siddharth"
last_name = "Pamnath"

# %%
# Understanding variables types 
# Python is dynamically typed, type of variable is determined at runtime 

age = 35
height = 2.4
name = "Siddharth"
is_student = True

print(type(name))
# Out:
# <class 'str'>

# %%
##Type Checking and Conversion 
age_1 = 23
type(age_1)

#  Type conversion 

age_str = str(age)
print(age_str)
print(type(age_str))
print(type(int(age_str)))
# Out:
# 35
# <class 'str'>
# <class 'int'>

# %%
name_2 = "Siddharth"
print(int(name_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 name_2 = "Siddharth"
# ----> 2 print(int(name_2))
#
# ValueError: invalid literal for int() with base 10: 'Siddharth'

# %%
height_3 = 5.11
type(height)
float(int(height))
# Out:
# 2.0

# %%
# Dynamic Typing
# Python Allows the type of a variable to change as the progra  executes

var = 10 
print(var,type(var))

var = "Hello"
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>

# %%
# Int 

age = input("What is the age ")
print("Age",age)
# Out:
# Age 2
