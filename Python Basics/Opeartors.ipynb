# %%
# Arithmetic operators : Addition , substraction , multiplication , division, floor division, modulus ,exponential 
# Comparison Operator : Equal to , Not equal to, Greater than , Less than , Greater than or equal to , Less than or equal to 
# Logical operator: AND ,OR, NOT

# %%
#  Arithmetic operators 
a=10 
b=5

c = a+b
sub = a-b
mul = a * b
div = a/b
floor_div_results = a/b
modules = a%b

print(c)
print(sub)
print(mul)
print(div)
print(floor_div_results)
print(modules)
# Out:
# 15
# 5
# 50
# 2.0
# 2.0
# 0

# %%
# Comparison operator 

a=10
b=10

a==b
# Out:
# True

# %%
str2 = "sidd"
str2= "sidd"
str2==str2
# Out:
# True

# %%
str2!=str2
# Out:
# False

# %%
# Greater than 
a = 45
b = 3
b>a
# Out:
# True

# %%
# less than 
a<b
# Out:
# False

# %%
# Greter than or equal to 
number1 = 45
number2 = 32

number1>=number2
# Out:
# True

# %%
number1<=number2
# Out:
# False

# %%
# Logical Operators 
# AND , NOT , OR

X = True
Y = True

result = X and Y 
print(result)
# Out:
# True

# %%
# AND 
X = True
Y = False

result = X and Y 
print(result)
# Out:
# False

# %%
# OR 
X = False
Y = False

result = X and Y 
print(result)
# Out:
# False

# %%
# NOT Operator
X = True
not X
# Inverse of x
# Out:
# False

# %%
# Simple calculator 

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Performing arithmetic operation 
addition = num1 + num2
substraction  = num1 - num2
multiplication = num1 * num2
division = num1/num2
floor_division  = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2 

# Displaying results 

print("addition",addition)
print("substraction",substraction)
print("multiplication",multiplication)
print("division",division)
print("floor_division",floor_division)
print("modulus",modulus)
print("exponentiation",exponentiation)
# Out:
# addition 4.1
# substraction -0.10000000000000009
# multiplication 4.2
# division 0.9523809523809523
# floor_division 0.0
# modulus 2.0
# exponentiation 4.2870938501451725
